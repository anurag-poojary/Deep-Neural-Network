# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import mnist

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Preprocess the data
x_train = x_train.reshape(60000, 784).astype('float32') / 255
x_test = x_test.reshape(10000, 784).astype('float32') / 255
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Create a function to build the model
def build_model(activation_function):
    model = Sequential()
    model.add(Dense(128, input_shape=(784,)))
    model.add(Activation(activation_function))
    model.add(Dense(64))
    model.add(Activation(activation_function))
    model.add(Dense(10))
   
    if activation_function == 'softmax':
        model.add(Activation(activation_function))
    else:
        model.add(Activation('softmax'))  # Use softmax for final layer for multi-class classification
   
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# List of activation functions to try
activation_functions = ['sigmoid', 'tanh', 'relu']

# Train and evaluate models for each activation function
for activation in activation_functions:
    print(f"\nTraining with {activation} activation function:")
   
    model = build_model(activation)
   
    # Train the model
    model.fit(x_train, y_train, epochs=5, batch_size=128, verbose=1, validation_data=(x_test, y_test))
   
    # Evaluate the model
    score = model.evaluate(x_test, y_test, verbose=0)
    print(f"Test loss: {score[0]}")
    print(f"Test accuracy: {score[1]}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
#
# Training with sigmoid activation function:
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6868 - loss: 1.3178 - val_accuracy: 0.9168 - val_loss: 0.3166
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9177 - loss: 0.2991 - val_accuracy: 0.9368 - val_loss: 0.2200
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9413 - loss: 0.2076 - val_accuracy: 0.9478 - val_loss: 0.1787
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9516 - loss: 0.1677 - val_accuracy: 0.9558 - val_loss: 0.1523
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9604 - loss: 0.1382 - val_accuracy: 0.9603 - val_loss: 0.1354
# Test loss: 0.1353633850812912
# Test accuracy: 0.9603000283241272
#
# Training with tanh activation function:
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8445 - loss: 0.5711 - val_accuracy: 0.9432 - val_loss: 0.1906
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9508 - loss: 0.1725 - val_accuracy: 0.9587 - val_loss: 0.1351
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9646 - loss: 0.1213 - val_accuracy: 0.9654 - val_loss: 0.1113
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9727 - loss: 0.0891 - val_accuracy: 0.9703 - val_loss: 0.0972
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9787 - loss: 0.0704 - val_accuracy: 0.9714 - val_loss: 0.0934
# Test loss: 0.09343694150447845
# Test accuracy: 0.9714000225067139
#
# Training with relu activation function:
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8310 - loss: 0.6075 - val_accuracy: 0.9516 - val_loss: 0.1626
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9564 - loss: 0.1510 - val_accuracy: 0.9617 - val_loss: 0.1199
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9707 - loss: 0.0973 - val_accuracy: 0.9713 - val_loss: 0.0973
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9778 - loss: 0.0739 - val_accuracy: 0.9737 - val_loss: 0.0833
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9834 - loss: 0.0549 - val_accuracy: 0.9757 - val_loss: 0.0796
# Test loss: 0.07962629199028015
# Test accuracy: 0.9757000207901001

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Preprocess the data
x_train = x_train.reshape(60000, 784).astype('float32') / 255
x_test = x_test.reshape(10000, 784).astype('float32') / 255
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Create a function to build the model
def build_model(activation_function):
    model = Sequential()
    model.add(Dense(128, input_shape=(784,)))
    model.add(Activation(activation_function))
    model.add(Dense(64))
    model.add(Activation(activation_function))
    model.add(Dense(10))
   
    if activation_function == 'softmax':
        model.add(Activation(activation_function))
    else:
        model.add(Activation('softmax'))  # Use softmax for final layer for multi-class classification
   
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# List of activation functions to try
activation_functions = ['sigmoid', 'tanh', 'relu','softmax']

# Function to plot training history
def plot_history(history, activation_function):
    # Plot training & validation accuracy values
    plt.figure(figsize=(12, 5))
    
    # Accuracy plot
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title(f'Model accuracy with {activation_function}')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper left')
    
    # Loss plot
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title(f'Model loss with {activation_function}')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper left')
    
    # Show plots
    plt.tight_layout()
    plt.show()

# Train and evaluate models for each activation function
for activation in activation_functions:
    print(f"\nTraining with {activation} activation function:")
   
    model = build_model(activation)
   
    # Train the model and save the training history
    history = model.fit(x_train, y_train, epochs=5, batch_size=128, verbose=1, validation_data=(x_test, y_test))
   
    # Evaluate the model
    score = model.evaluate(x_test, y_test, verbose=0)
    print(f"Test loss: {score[0]}")
    print(f"Test accuracy: {score[1]}")
    
    # Plot the training history
    plot_history(history, activation)
# Out:
# Training with sigmoid activation function:
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6453 - loss: 1.3699 - val_accuracy: 0.9131 - val_loss: 0.3266
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9217 - loss: 0.2942 - val_accuracy: 0.9360 - val_loss: 0.2247
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9383 - loss: 0.2119 - val_accuracy: 0.9483 - val_loss: 0.1801
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9516 - loss: 0.1679 - val_accuracy: 0.9546 - val_loss: 0.1534
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9606 - loss: 0.1364 - val_accuracy: 0.9596 - val_loss: 0.1338
# Test loss: 0.1337975710630417
# Test accuracy: 0.9595999717712402
# Training with tanh activation function:
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8425 - loss: 0.5628 - val_accuracy: 0.9427 - val_loss: 0.1967
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9505 - loss: 0.1733 - val_accuracy: 0.9605 - val_loss: 0.1359
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9649 - loss: 0.1189 - val_accuracy: 0.9633 - val_loss: 0.1205
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9751 - loss: 0.0863 - val_accuracy: 0.9702 - val_loss: 0.0973
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9804 - loss: 0.0668 - val_accuracy: 0.9718 - val_loss: 0.0921
# Test loss: 0.09208076447248459
# Test accuracy: 0.9718000292778015
# Training with relu activation function:
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8214 - loss: 0.6225 - val_accuracy: 0.9511 - val_loss: 0.1657
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9573 - loss: 0.1435 - val_accuracy: 0.9639 - val_loss: 0.1169
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9706 - loss: 0.0989 - val_accuracy: 0.9722 - val_loss: 0.0914
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9794 - loss: 0.0690 - val_accuracy: 0.9724 - val_loss: 0.0927
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9841 - loss: 0.0528 - val_accuracy: 0.9738 - val_loss: 0.0842
# Test loss: 0.08419971168041229
# Test accuracy: 0.973800003528595
# Training with softmax activation function:
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.2304 - loss: 2.2746 - val_accuracy: 0.8168 - val_loss: 2.0408
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8135 - loss: 1.8808 - val_accuracy: 0.8479 - val_loss: 1.3549
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8445 - loss: 1.2108 - val_accuracy: 0.8521 - val_loss: 0.8497
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8474 - loss: 0.7819 - val_accuracy: 0.8539 - val_loss: 0.6235
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8565 - loss: 0.5898 - val_accuracy: 0.8590 - val_loss: 0.5209
# Test loss: 0.5209072828292847
# Test accuracy: 0.859000027179718
